# %% [markdown]
# # Analysis on whole corpus

# %% [markdown]
# 1. LDA
# 2. Word2Vec
# 3. KMeans

# %%
import nltk
from nltk import FreqDist
from nltk.collocations import *
from nltk.util import ngrams
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize,word_tokenize
import re
import os
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
import gensim
from gensim.models.word2vec import Word2Vec
from sklearn.manifold import TSNE
from bokeh.io import output_notebook
from bokeh.plotting import show, figure
from textblob import TextBlob
# %matplotlib inline
# Out:
# C:\Users\Sen\AppData\Local\Continuum\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
path = "C:/Users/Sen/Downloads/CUS 635 (Web data mining)/Project/Data/Combined/"
prefix = os.listdir(path)
#print(prefix)

# %% [markdown]
# Functions for normalization

# %%
#Normalization
def remove_utf(text):
    return re.sub(r'[^\x00-\x7f]',r' ',text)

def remove_punctuation(corpus):
    punctuations = ".,\"-\\/#!?$%\^&\*;:{}=\-_'~()"    
    filtered_corpus = [token for token in corpus if (not token in punctuations)]
    return filtered_corpus

def apply_stopwording(corpus, min_len):
    filtered_corpus = [token for token in corpus if (not token in stopwords.words('english') and len(token)>min_len)]
    return filtered_corpus

def removeAbb(x):
    lst = {'Dx':'diagnosed' ,
           'Rx':'prescription',
           'OTC':'Over The Counter',
           'DFL':'Drug Fact Label',
           'AUT':'Application Under Test'}
    for i in x:
        if i in lst:
            i = lst[i]
    return x

def apply_lemmatization(corpus):
    lemmatizer = nltk.WordNetLemmatizer()
    normalized_corpus = [lemmatizer.lemmatize(token) for token in corpus]
    return normalized_corpus
# Out:
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <input>:6: DeprecationWarning: invalid escape sequence \^
# <ipython-input-34-154e7d5c015e>:6: DeprecationWarning: invalid escape sequence \^
#   punctuations = ".,\"-\\/#!?$%\^&\*;:{}=\-_'~()"

# %% [markdown]
# Removing Punctuations & Stopwording

# %%
#Read the dataset
dataset={} #nltk text from tokens
dataset_raw = {} 
allFeatures=set()
tot_articles = 0
articles_count={}
raw_corpus = {} #used in sumerization
dataset2= set()
dataset3=[]
N={} # Number of articles in each corpus

for i,_ in enumerate(prefix):
    fileName = path + prefix[i]
    f=open(fileName,'r',encoding="utf8")
    text = ''
    text_raw = '' 
    
    lines = f.readlines()
    #print(_,'OK') #load test
    tot_articles+=len(lines)
    articles_count[str(_)] = len(lines)
    dataset_raw[str(_)] = list(map(lambda line: line.lower(), lines))

    for line in lines:
        dataset2.add(line.lower())
        dataset3.append(remove_utf(line.lower()))
        text+=line.replace('\n',' ').lower()
        text_raw = line.lower()
    f.close
    N[str(_)]=len(lines)
    
    tokens = nltk.word_tokenize(text)
    dataset[str(_)] = nltk.Text(tokens)
    raw_corpus[_] = text

# %%
#Preprocessing
dataset_clean={} #dict of tokens

for i in dataset:
    #print ('Processing %s' % str(i))
    dataset_clean[i] = apply_lemmatization(removeAbb(apply_stopwording(remove_punctuation(dataset[i]), 3)))
    #print (dataset_clean[i])


#create a nltk.Text dict with clened dataset
clean_text = {}
for i in dataset_clean:
    clean_text[i] = nltk.Text(dataset_clean[i])

clean_text2 = ""
for i in raw_corpus:
    clean_text2 = raw_corpus[i]

# %%
from nltk.corpus import wordnet
tokens = []

def get_lemma(token):
    #Return the morphological variant of this word
    lemma = wordnet.morphy(token)

    if lemma is None:
        return token
    else:
        return lemma

lemmas = [get_lemma(token) for token in tokens]
stop_words= set(nltk.corpus.stopwords.words('english'))
tokens_clean = [token for token in lemmas if (len(token)>4 and token not in stop_words)]

def clean_tokens(text):
    tokens_raw = nltk.word_tokenize(text)
    tokens = []
    for token in tokens_raw:
        if (token == " " or token.startswith('http') or token.startswith('@')):
            continue
        else:
            tokens.append(token)
    
    lemmas = [get_lemma(token) for token in tokens]
    tokens_clean = [token for token in lemmas if (len(token)>4 and token not in stop_words)]
    return tokens_clean

tokens = [clean_tokens(token) for token in dataset3]

# %% [markdown]
# # LDA

# %% [markdown]
# To discover the main topics, the focus group is talking about, LDA (Latent Dirichlet Allocation) is used which gives the best results on the focus group data using four clusters of words. The main topic in the corpus is a study about prostate cancer symptoms and the second biggest topic is consumer product labels that are related to prostate cancer. Some of the important topics are shown below.

# %%
from gensim import corpora
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(tweet) for tweet in tokens]

import gensim
k=4
iterations = 20
topic_model = gensim.models.ldamodel.LdaModel(corpus, num_topics=k, id2word = dictionary, passes = iterations)
topics = topic_model.print_topics(num_words = 4)
for topic in topics:
    print (topic)
# Out:
# (0, '0.019*"prostate" + 0.016*"cancer" + 0.012*"think" + 0.011*"symptom"')
# (1, '0.016*"patient" + 0.012*"might" + 0.012*"consumer" + 0.011*"label"')
# (2, '0.028*"symptom" + 0.021*"would" + 0.017*"study" + 0.014*"conditions"')
# (3, '0.016*"condition" + 0.014*"symptom" + 0.012*"benign" + 0.010*"treat"')

# %%
import pyLDAvis.gensim
lda_vis = pyLDAvis.gensim.prepare(topic_model,corpus,dictionary,sort_topics=False)
pyLDAvis.display(lda_vis)
# Out:
# C:\Users\Sen\AppData\Local\Continuum\Anaconda3\lib\site-packages\pyLDAvis\_prepare.py:387: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   topic_term_dists = topic_term_dists.ix[topic_order]
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el2020821726671602807318612742"></div>
# <script type="text/javascript">
#
# var ldavis_el2020821726671602807318612742_data = {"mdsDat": {"Freq": [15.604673669697103, 11.826581888116365, 58.43750689886819, 14.131237543318331], "cluster": [1, 1, 1, 1], "topics": [1, 2, 3, 4], "x": [-0.03561348838754388, 0.10032864560135436, 0.02723889901253369, -0.09195405622634417], "y": [-0.05431408022008791, 0.06317151258456134, -0.07623523536981773, 0.06737780300534424]}, "tinfo": {"Category": ["Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4"], "Freq": [52.0, 21.0, 23.0, 40.0, 27.0, 13.0, 10.0, 29.0, 14.0, 48.0, 9.0, 16.0, 46.0, 14.0, 20.0, 11.0, 61.0, 7.0, 30.0, 10.0, 6.0, 8.0, 24.0, 25.0, 9.0, 6.0, 12.0, 16.0, 12.0, 17.0, 2.9392376544611603, 2.247843896389478, 2.2473247001999783, 2.247209656728317, 2.198270163883421, 1.5562964135629085, 1.5561832041176065, 1.5561898733043695, 1.5560803319117873, 1.5560368154681588, 1.5560543220834115, 1.5560196423122439, 1.555972958004903, 1.555966455547809, 1.5559371111260518, 1.5559427799348005, 1.5557360351451475, 1.5555542998058558, 1.5554624317581955, 1.555332549345986, 2.9415138479033716, 2.9399475893920815, 0.864611212029683, 0.864611212029683, 0.864611212029683, 0.864611212029683, 0.864611212029683, 0.8646111286648485 ...

# %% [markdown]
# # Word2Vec

# %% [markdown]
# Word2vec comes in action to discover words in the corpus that share common context which produces vector space of several hundreds of dimensions, to reduce the dimensionality TSNE is used to word vectors to transform the 64-dimensional space into a 2D space and by using the bokeh.iobokeh.io library we can visualize the output.

# %%
cleantokens=[]
for i in dataset_clean.values():
    cleantokens+=i
#print (cleantokens[0:10])

# %%
w2v_model = Word2Vec([cleantokens],size=32, sg=1, window = 5, min_count=3, seed = 20, workers=2)
print (len(w2v_model.wv.vocab))
# Out:
# 520

# %%
w2v_model.most_similar('patient')
# Out:
# C:\Users\Sen\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('seems', 0.9988170862197876),
#  ('standard', 0.9987940192222595),
#  ('support', 0.998788058757782),
#  ('experience', 0.9987757205963135),
#  ('using', 0.9987719058990479),
#  ('treatment', 0.9987670183181763),
#  ('physician', 0.9987419247627258),
#  ('stopping', 0.9987385272979736),
#  ('understand', 0.9987282752990723),
#  ('data', 0.9987208843231201)]

# %%
#Retrieving the vocabulary from the 64-dimensional space
X_32D=w2v_model[w2v_model.wv.vocab]
# Transform the data and load up a Panda dataframe
tSNE = TSNE(n_components=2, n_iter=1000)
X_2D = tSNE.fit_transform(X_32D)
x2D_df = pd.DataFrame(X_2D, columns=['x','y'])
x2D_df['word'] = w2v_model.wv.vocab.keys()
x2D_df.head(10)
# Out:
# C:\Users\Sen\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#            x          y        word
# 0   5.358952   1.388488        dont
# 1  10.374302  23.426588       think
# 2  14.473792  29.530200     patient
# 3 -20.219520  17.336686        seem
# 4   9.861067   2.174397        able
# 5  10.402093  19.592857        make
# 6  14.751413  -0.988324     correct
# 7  25.767955  -0.327661    decision
# 8  22.321907   0.682656  understand
# 9  22.813262 -11.358965       issue

# %%
# Configure the notebook to generate graph in a cell
# Always call this method before any visualization
output_notebook()

# Extract a sample. If you have a powerful computer you can display all 17,000
plot = figure(plot_width=800, plot_height=800)
_ = plot.text(x=x2D_df.x, y=x2D_df.y, text=x2D_df.word)
show(plot)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8a581ffa-84f2-451e-8be9-0e7083fe173a">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b1c57462-2792-4674-ab39-532830fd81c9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b1c57462-2792-4674-ab39-532830fd81c9");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b1c57462-2792-4674-ab39-532830fd81c9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b1c57462-2792-4674-ab39-532830fd81c9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a8255380-f3f0-405b-9592-c112c5c0e2e0":{"roots":{"references":[{"attributes":{"plot":{"id":"7dcb5f9d-469b-4b7b-bc6a-82d21d0fe92a","subtype":"Figure","type":"Plot"},"ticker":{"id":"1d06f7e7-086e-4ad6-8618-f359baa272eb","type":"BasicTicker"}},"id":"d13b580d-3ba4-40cf-9ffb-a36525722ea0","type":"Grid"},{"attributes":{"formatter":{"id":"e772d037-ac08-4c1f-8ae1-b7438785f643","type":"BasicTickFormatter"},"plot":{"id":"7dcb5f9d-469b-4b7b-bc6a-82d21d0fe92a","subtype":"Figure","type":"Plot"},"ticker":{"id":"06874549-0c9c-4dbc-a5d1-0b346f17c408","type":"BasicTicker"}},"id":"885b8b08-b285-49d2-bde5-9d8cbcc87e46","type":"LinearAxis"},{"attributes":{},"id":"ee5a4da7-7fea-45ed-990e-1b4183d33d1a","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"7dcb5f9d-469b-4b7b-bc6a-82d21d0fe92a","subtype":"Figure","type":"Plot"},"ticker":{"id":"06874549-0c9c-4dbc-a5d1-0b346f17c408","type":"BasicTicker"}},"id":"55e9f457-70ad-42bd-a546-2f909efb5c64","type":"Grid"},{"attributes":{"callback":null},"id":"caccf700-6ab1-43d1-84b7-d27ec296f4eb","type":"DataRange1d"},{"attributes":{"plot":{"id":"7dcb5f9d-469b-4b7b-bc6a-82d21d0fe92a","subtype":"Figure","type":"Plot"}},"id":"44def228-37f1-4739-a82a-c25c75a7654f","type":"HelpTool"},{"attributes":{"plot":null,"text":""},"id":"bc3f60ca-042e-4711-803a-080a84337a6b","type":"Title"},{"attributes":{"plot":{"id":"7dcb5f9d-469b-4b7b-bc6a-82d21d0fe92a","subtype":"Figure","type":"Plot"}},"id":"87a3062a-bada-4fee-b7e1-3c2e0b0df284","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e4c8387c-baf9-42cc-8e1c-e0362b810876","type":"BoxAnnotation"},{"attributes":{},"id":"06874549-0c9c-4dbc-a5d1-0b346f17c408","type":"BasicTicker"},{"attributes":{"plot":{"id":"7dcb5f9d-469b-4b7b-bc6a-82d21d0fe92a","subtype":"Figure","type":"Plot"}},"id":"f298c344-307e-4418-8308-da636a5ad547","type":"PanTool"},{"attributes":{},"id":"ffd53c55-84bc-4dd1-8464-df17858fc83c","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"ffd53c55-84bc-4dd1-8464-df17858fc83c","type":"BasicTickFormatter"},"plot":{"id":"7dcb5f9d-469b-4b7b-bc6a-82d21d0fe92a","subtype":"Figure","type":"Plot"},"ticker":{"id":"1d06f7e7-086e-4ad6-8618-f359baa272eb","type":"BasicTicker"}},"id":"26c92f78-d41a-41ae-81e8-2a9002d8f85b","type":"LinearAxis"},{"attributes":{"data_source":{"id":"84fcfd33-3978-46a7-b3cf-2c0f0365ae57","type":"ColumnDataSource"},"glyph":{"id":"66591661-8b6a-4e07-b9a9-8b5687676c32","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b9534444-2980-4bfb-b8e6-0a1b84baa722","type":"Text"},"selection_glyph":null},"id":"93d1a2e4-15ed-44d7-929f-67e1f2b468be","type":"GlyphRenderer"},{"attributes":{"text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b9534444-2980-4bfb-b8e6-0a1b84baa722","type":"Text"},{"attributes":{},"id":"e772d037-ac08-4c1f-8ae1-b7438785f643","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"7dcb5f9d-469b-4b7b-bc6a-82d21d0fe92a","subtype":"Figure","type":"Plot"}},"id":"1ae2152d-6350-46a9-a8b2-0c2c13f729b1","type":"ResetTool"},{"attributes":{"below":[{"id":"26c92f78-d41a-41ae-81e8-2a9002d8f85b","type":"LinearAxis"}],"left":[{"id":"885b8b08-b285-49d2-bde5-9d8cbcc87e46","type":"LinearAxis"}],"plot_height":800,"plot_width":800,"renderers":[{"id":"26c92f78-d41a-41ae-81e8-2a9002d8f85b","type":"LinearAxis"},{"id":"d13b580d-3ba4-40cf-9ffb-a36525722ea0","type":"Grid"},{"id":"885b8b08-b285-49d2-bde5-9d8cbcc87e46","type":"LinearAxis"},{"id":"55e9f457-70ad-42bd-a546-2f909efb5c64","type":"Grid"},{"id":"e4c8387c-baf9-42cc-8e1c-e0362b810876","type":"BoxAnnotation"},{"id":"93d1a2e4-15ed-44d7-929f-67e1f2b468be","type":"GlyphRenderer"}],"title":{"id":" ...

# %%
print(w2v_model.most_similar(positive=['patient','risk','cancer']))
# Out:
# [('data', 0.9995294213294983), ('self-selection', 0.9993284940719604), ('trial', 0.999263346195221), ('study', 0.9992446303367615), ('underlying', 0.9992426633834839), ('treatment', 0.9992210865020752), ('would', 0.9992092847824097), ('might', 0.9992082118988037), ('company', 0.9992051720619202), ('benefit', 0.9991835355758667)]
# C:\Users\Sen\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # KMeans

# %%
def apply_stemming(text):
    stemmer = nltk.PorterStemmer()
    normalized_text = [stemmer.stem(token) for token in text]
    return normalized_text

# %%
clean_tokens2= []
tokenized_token = []
index = 1
for token in dataset2:
    index+=1
    tokens = apply_stopwording(remove_punctuation(nltk.Text(nltk.word_tokenize(token))), 3)
    clean_text = apply_stemming(tokens)
    #print ('[%s] - %s' % (index, clean_text))
    clean_tokens2.append(clean_text)
    tokenized_token.append(tokens)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
documents = [str((i)) for i in clean_tokens2]
#Tf-idf matrix
tfidf_vectorizer = TfidfVectorizer(min_df=1)
tfidf_matrix = tfidf_vectorizer.fit_transform(documents)
#print(documents)
#print(tfidf_matrix)
features=tfidf_vectorizer.get_feature_names()
#print(features)
#print(tfidf_matrix.shape)
# Out:
# C:\Users\Sen\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:1059: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):

# %%
lemmas_list=[]
token_list=[]

lemmas_list.extend(l for lemma in clean_tokens2 for l in lemma)
token_list.extend(t for token in tokenized_token for t in token)

#token_dataframe = pd.DataFrame({'terms': token_list}, index = lemmas_list)
#print(token_dataframe.head(10))

# %%
from sklearn.cluster import KMeans
k = 6
k_means = KMeans(n_clusters=k)
# %time k_means.fit(tfidf_matrix)
clusters = k_means.labels_.tolist()
tokens_space = {'term':documents, 'cluster':clusters}
kmean_dataframe = pd.DataFrame(tokens_space,index=[clusters], columns =['term','cluster'])

n=5

print ('Top %s terms within clusters' % n)
print()

sorted_centroids = k_means.cluster_centers_.argsort()[:, ::-1]
sent =""

for cluster_number in range(k):
    token_string = ''
    
    for ind in sorted_centroids[cluster_number, :n]:
        token_string = token_string + token_dataframe.loc[features[ind].split(' ')].values.tolist()[0][0] + ', '
    
    sent= sent + token_string
    print(token_string)
    print()
    print(type(token_string))
    print("Cluster %d: %s" % (cluster_number, token_string))
# Out:
# Top 5 terms within clusters
#
# would, trials, version, point, good,
#
# <class 'str'>
# Cluster 0: would, trials, version, point, good,
# patients, symptoms, conditions, consumers, warnings,
#
# <class 'str'>
# Cluster 1: patients, symptoms, conditions, consumers, warnings,
# prostat, symptoms, cancer, urinary, label,
#
# <class 'str'>
# Cluster 2: prostat, symptoms, cancer, urinary, label,
# dipstick, studies, actual, many, doctor,
#
# <class 'str'>
# Cluster 3: dipstick, studies, actual, many, doctor,
# information, needed, rate, wade, population,
#
# <class 'str'>
# Cluster 4: information, needed, rate, wade, population,
# think, symptoms, tamsulosin, diagnosis, hydrochloride,
#
# <class 'str'>
# Cluster 5: think, symptoms, tamsulosin, diagnosis, hydrochloride,
