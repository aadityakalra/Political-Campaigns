# %% [markdown]
# # FocusGroupBot
# ![image.png](attachment:image.png)

# %%
#pip install chatterbot in cmd
from chatterbot import ChatBot
from chatterbot.trainers import ListTrainer
import pandas as pd

# %%
chatbot = ChatBot('FocusGroupBot', logic_adapters=[
        {
            "import_path": "chatterbot.logic.BestMatch",
            "statement_comparison_function": "chatterbot.comparisons.levenshtein_distance",
            "response_selection_method": "chatterbot.response_selection.get_first_response"
        }])

# %% [markdown]
# # Training the chatbot

# %%
chatbot.set_trainer(ListTrainer)

# %%
f = open('./trainbot.txt','r',encoding="utf8").readlines()
chatbot.train(f)
#g = open('./definitions.txt','r',encoding="utf8").readlines()
#chatbot.train(g)
# Out:
# List Trainer: [####################] 100%

# %% [markdown]
# Question the bot trained on based on corpus and summary data.

# %%
Q = []
for i,ch in enumerate(f):
    x = ch.split(",")
    #Q['test'] = x[0]
    Q.append(x[0])
    
print(Q)
# Out:
# ['\ufeff"who are alpha blockers given to?"', '"who needs alpha blockers?"', '"What\'s in alpha blockers"', '"Issues with taking alpha blocker"', '"what can the OTC company do to warn consumers?"', '"the risk of tamsulosin hydrochloride?"', '"will the FDA be concerned about patients with preexcisting condition taking tamsulosin hydrochloride?"', '"should patients should be pre screened for cancer prior to treatment with tamsulosin hydrochloride capsules?"', '"Can consumers use a dipstick properly?"', '"Is a dipstick necessary?"', '"Are there any benefits of including a dipstick"', '"Any value in dipstick?"', '"what study was done on unine analysis?"', '"Can consumers really use a dipstick?"', '"what conclusion on dipstick?"', '"What is the inclusion criteria for this study?"', '"What is the exclusion criteria for this study?"', '"Which ones do you think are the absolute contraindications that would put men in such danger that if consumers with those contraindications incorrectly self-selected to use tamsulosin hydrochloride these errors would kill the OTC program?"', '"the role of product label?"', '"are we including orthostatic hypotension rx label"', '"is 3 or 4 weeks enough data to be superior to medical opinion"', '"will men byt this product?"', '"What should the label say?"', '"What are the urinary symptoms of prostatitis?"', '"What should be the discussion point?"', '"What are the issues with using the term ‘enlarged prostrate’?"', '"What is the purpose of saying ‘enlarged’?"', '"What happened in the label comprehension study work?"', '"What should be the wording on the label be?"', '"Who should the label be written for?"', '"Should ‘prostrate’ be included on the label?"', '"How would the consumer read the label?"', '"Does company have any information regarding tamsulosin?"', '"Should patients diagnose symptoms themselves?"', '"Can the consumer self-recognize the symptoms of the disease/condition?"', '"Are the Consumers missing any underlying condition while treating themselves?"', '"Is self-recognition an issue?"', '"Can self-selection be tested?"', '"What does OTCness mean?"', '"What is the difference between self-selection and self-diagnosis?"', '"What is the limitations of OTC label?"', '"Would extra dosage of drugs be risky?"', '""', '"doctor alpha blocker patients?"', '"Definition of alpha blockers"', '"possible side effects of alpha blocker"', '"how can drug companies do to warn consumers?"', '"side effects of tamsulosin hydrochloride?"', '"what patients should not take tamsulosin hydrochloride?"', '"patients pre screening for cancer before using hydrochloride capsules?"', '"study on dipstick usage?"', '"importance of dipstick in product development?"', '"any advantage of dipstick?"', '"better alternatice to using dipstick"', '"education on dipstick usage"', '"what conclusion on dipstick?"', '"who was included in the tamsulosin hydrochloride study"', '"who was excluded in the tamsulosin hydrochloride study"', '"definition of cancer"', '"serious side effects of tamsulosin hydrochloride that could result in the recall cancellation of OTC program?"', '"why do we need a product label?"', '"what is included in the rx label"', '"how long does it take to get a good medical opinion"', '"are men likely to this product?"', '"What should the label of the drug say?"', '"ambiguity of the term ‘enlarged prostrate’?"', '"did consumers patients undestand the description of what prostate urinary symptoms?"', '"what should go on the label for Prostate symptom reliever?"', '"Who should the label be written for?"', '"Should the word ‘prostrate’ appear on the label?"', '"Does company have any information regarding the prescribing of tamsulosin?"', '"Should patients self diagnose?"', '"Is self-recognition of Benign prostatic hyperplasia BPH an issue?"', '"Can self-selection be tested?"', '"What is the difference between self-selection vs self-diagnosis?"', '"What is the limitations of OTC label?"', '"risk of overdose?"', '"benign prosta ...

# %% [markdown]
# Q = []
# for i,ch in enumerate(train):
#     if i/2 != 0:
#         Q.append(ch)

# %% [markdown]
# Some random questions

# %%
Q_test = [
    "who are alpha blocker given to?",
    "What's in alpha blockers",
    "concerns of pre existing condition taking tamsulosin hydrochloride?",
    "will the FDA be concerned about patients with preexcisting condition taking tamsulosin hydrochloride?",
    "the risk of tamsulosin hydrochloride?",
    "should patients be pre screened prior to treatment with tamsulosin hydrochloride?",
    "Is a dipstick necessary?"
]

# %% [markdown]
# Test is out, ask it random stuff...
# "definition of *" for definitions

# %%
question = "Does company have any information regarding tamsulosin?"
print(chatbot.get_response(question))
# Out:
# Company does not have information that would allow us to understand whether physicians are prescribing tamsulosin to men with mild symptoms. In the OTC-simulated studies we did collect data about the use of the AUA recommended lifestyle modification (responses were 'ever used', 'still using' and 'never used')

# %%
question = "What is the limitations of OTC label?"
print(chatbot.get_response(question))
# Out:
# One of the occasional limitations of the OTC label is that the section on 'ask a doctor before use if' is separated from the section on 'stop use and ask a doctor if:...'

# %%
question = "What is the limitations of OTC label?"
print(chatbot.get_response(question))
# Out:
# One of the occasional limitations of the OTC label is that the section on 'ask a doctor before use if' is separated from the section on 'stop use and ask a doctor if:...'

# %%
for i in Q_test:
    print('User:', i)
    print('Bot:',chatbot.get_response(i))
    print()
# Out:
# User: who are alpha blocker given to?
# Bot: md provider will likely give alpha blocker to those pts as they do not have a full uds examination to review.
#
# User: What's in alpha blockers
# Bot: virtually all alpha blockers including tamsulosin have been studied with mostly all antihypertensive classes and the aes are not higher in those pts on antihypertensives.
#
# User: concerns of pre existing condition taking tamsulosin hydrochloride?
# Bot: who needs alpha blockers?
#
# User: will the FDA be concerned about patients with preexcisting condition taking tamsulosin hydrochloride?
# Bot: i think fda will be concerned about those men who have a concomitant condition with bph/luts who obtain partial relief from tamsulosin hydrochloride, are comfortable enough with the improvement not to bother getting checked out, and don't discuss their symptoms with their physician.
#
# User: the risk of tamsulosin hydrochloride?
# Bot: the incremental risk of trying tamsulosin hydrochloride would be low, as long as there are no contraindications. Plus the label and insert should be demonstrated to drive increased physician interactions.
#
# User: should patients be pre screened prior to treatment with tamsulosin hydrochloride?
# Bot: screening for prostate cancer prostate cancer and bph frequently co-exist; therefore, patients should be screened for the presence of prostate cancer prior to treatment with tamsulosin hydrochloride capsules and at regular intervals afterwards
#
# User: Is a dipstick necessary?
# Bot: Dipstick is an unnecessary complication in this process with limited yield of what is called a medically relevant condition. Dipstick is not necessary and will overly complicate the OTC paradigm with a drug and a device.
